# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading Dataset
def read_data():
    rent_df = pd.read_csv("D:/Python files/Python/House_Rent.csv")
    print("House Rent import Successfully!!")
    return rent_df

# %%
rent_df = read_data()
# Out:
# House Rent import Successfully!!

# %%
rent_df.sample(5)
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 4731  2022-06-24    2  13000   950       2 out of 2   Super Area
# 142   2022-05-06    2   8000   700  Ground out of 1   Super Area
# 3082  2022-07-06    3  75000  1900       3 out of 3  Carpet Area
# 275   2022-07-04    4  30000  4000  Ground out of 3   Super Area
# 2122  2022-06-23    1   8500   500       2 out of 4   Super Area
#
#                     Area Locality       City Furnishing Status  \
# 4731   Manikonda, Outer Ring Road  Hyderabad       Unfurnished
# 142   Sakher Bazar, Purba Barisha    Kolkata       Unfurnished
# 3082                  Gopalapuram    Chennai    Semi-Furnished
# 275   Sakher Bazar, Purba Barisha    Kolkata         Furnished
# 2122                     Hulimavu  Bangalore    Semi-Furnished
#
#       Tenant Preferred  Bathroom Point of Contact
# 4731  Bachelors/Family         2    Contact Owner
# 142   Bachelors/Family         1    Contact Owner
# 3082            Family         3    Contact Agent
# 275   Bachelors/Family         3    Contact Agent
# 2122  Bachelors/Family         1    Contact Owner

# %%
print(rent_df.columns.values)
# Out:
# ['Posted On' 'BHK' 'Rent' 'Size' 'Floor' 'Area Type' 'Area Locality'
#  'City' 'Furnishing Status' 'Tenant Preferred' 'Bathroom'
#  'Point of Contact']

# %%
#Checking info of the Dataset
rent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
#Checking shape of the Dataset
print("House Rent data shape =", rent_df.shape)
# Out:
# House Rent data shape = (4746, 12)

# %%
#Checking all the Columns in the Dataset
print("House Rent data Columns =",rent_df.columns)
# Out:
# House Rent data Columns = Index(['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact'],
#       dtype='object')

# %%
rent_df.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
# Checking if there is any Null value present in the Dataset?
rent_df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
#Checking if there is any Duplicate value present in the Dataset?
rent_df.duplicated().sum()
# Out:
# 0

# %%
#Checking Mean, Median, Maximum & Minimum House Rents
print("Mean House Rent:", round(rent_df["Rent"].mean()))
print("Median House Rent:",round(rent_df["Rent"].mean()))
print("Highest House Rent:", round(rent_df["Rent"].max()))
print("Lowest House Rent:", round(rent_df["Rent"].min()))
# Out:
# Mean House Rent: 34993
# Median House Rent: 34993
# Highest House Rent: 3500000
# Lowest House Rent: 1200

# %%
#Highest House Rents present in the Dataset
rent_df["Rent"].sort_values(ascending=False)[:5]
# Out:
# 1837    3500000
# 1001    1200000
# 827     1000000
# 1329     850000
# 1459     700000
# Name: Rent, dtype: int64

# %%
#Lowest House Rents present in the Dataset
rent_df["Rent"].sort_values()[:5]
# Out:
# 4076    1200
# 285     1500
# 471     1800
# 2475    2000
# 146     2200
# Name: Rent, dtype: int64

# %%
# Showing Barplot for Rent
plt.figure(figsize=(20,7))
sns.barplot(x = rent_df.Rent)
# Out:
# <AxesSubplot:xlabel='Rent'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x = rent_df.City, y = rent_df.Rent)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Rent'>

# %%
# Bar Plot for Number of House in Each City which is Available for Rent
from IPython.display import Image
plt.figure(figsize=(30,7))
Image("https://i.imgur.com/AIJYYKl.png")

# %%
sns.set_context("poster" , font_scale= .9)
plt.figure(figsize=(20,6))
ax = rent_df["City"].value_counts().plot(kind = 'bar',color = "crimson",rot = 0)

for p in ax.patches:
    ax.annotate(int(p.get_height()),(p.get_x() + 0.25,p.get_height()-100),ha = "center",va ="bottom",color = "white")

# %%
# Bar Plot on Different Types of Tenant Preferred
sns.set_context("poster",font_scale= .9)
plt.figure(figsize=(20,6))
ax = rent_df["Furnishing Status"].value_counts().plot(kind = 'bar',color = 'blue',rot = 0)

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() - 250), ha = 'center', va = 'bottom', color = 'Black')

# %%
sns.set_context("poster",font_scale = .8)
plt.figure(figsize =(20,6))
ax = rent_df["Tenant Preferred"].value_counts().plot(kind = 'bar',color ='Green',rot = 0)

for p in ax.patches:
    ax.annotate(int(p.get_height()),(p.get_x() + 0.25,p.get_height()-300),ha = 'center',va ='bottom',color ='White')

# %%
# Pie Plot on Cities to check the distribution
plt.figure(figsize = (20, 8))
counts = rent_df["City"].value_counts()
explode = (0, 0, 0, 0, 0, 0.1)
colors = ['#FF1E00', '#A66CFF', '#EAE509', '#D61C4E', '#3CCF4E', '#3AB4F2']

counts.plot(kind = 'pie', colors = colors, explode = explode, autopct = '%1.1f%%')
plt.axis('equal')
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %%
# Scatter Plot on House Rents vs House Sizes
plt.figure(figsize= (20,6))
plt.ticklabel_format(style= 'plain')
plt.scatter(rent_df["Size"],rent_df["Rent"])
plt.xlabel("Size")
plt.ylabel("Rent")
# Out:
# Text(0, 0.5, 'Rent')

# %%
# Relationship between House Rent vs House Sizes

x = rent_df["Rent"]
y = rent_df["Size"]
colors = rent_df["Size"]
sizes = rent_df["Size"]

plt.figure(figsize= (25,8))
plt.ticklabel_format(style= 'plain')
plt.scatter(x,y,c = colors ,s = sizes,alpha= 0.3 ,cmap= 'viridis')
plt.colorbar();

# %%
# Bar Plot for City vs House Rent
plt.figure(figsize=(20,7))
sns.barplot(x = rent_df ['City'],y = rent_df['Rent'],palette= 'nipy_spectral');

# %%
# Histogram on House Sizes
n_bins = 20
plt.figure(figsize= (20,6))
rent_df["Size"].hist(bins = n_bins)
# Out:
# <AxesSubplot:>

# %%
# Distribution of different number of BHK available in the Dataset
sns.set_context('poster',font_scale=.8)
plt.figure(figsize=(40,8))
ax= rent_df["BHK"].value_counts().plot(kind = 'bar',color = 'Blue',rot =0)

for p in ax.patches:
    ax.annotate(int(p.get_height()),(p.get_x() + 0.25,p.get_height() + 1), ha = 'center', va = 'bottom', color = 'Black')

# %%
# Distribution of different number of Bathrooms available in the Dataset
sns.set_context("poster", font_scale = .8)
plt.figure(figsize = (30, 10))
ax = rent_df["Bathroom"].value_counts().plot(kind = 'bar', color = "Green", rot = 0)

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'Black')

# %%
plt.figure(figsize=(20,6))
colormap = plt.cm.plasma
sns.heatmap(pd.crosstab(rent_df["Area Type"],rent_df["BHK"]),cmap=colormap)
# Out:
# <AxesSubplot:xlabel='BHK', ylabel='Area Type'>

# %%
# Thank You!!
